# %%
import hyperspy.api as hs

from utils.getting_spectral_lines_from_hspy import get_spesific_lines_from_hspy
from utils.get_raw_data import locate_raw_data, get_multiple_data_arrays
from utils.helper_plotting import plotly_plot_multiple_spectra

emsa = locate_raw_data()

# %%
ga30 = get_multiple_data_arrays(filters=["GaAs_30"])
s = hs.load(emsa[6], signal_type="EDS_SEM")
s.plot()

# %%
s.find_peaks1D_ohaver()
# Out:
# [########################################] | 100% Completed | 118.43 ms
# array([array([( 0.01789093,  49.63826657, 0.06950149),
#               ( 1.10579383, 128.90055035, 0.11039993),
#               ( 1.29377947,  86.78523218, 0.1219683 ),
#               ( 9.23792958,  82.2448964 , 0.24377416),
#               (10.5238407 ,  64.18895966, 0.2626254 )],
#              dtype=[('position', '<f8'), ('height', '<f8'), ('width', '<f8')])],
#       dtype=object)

# %%
P = s.find_peaks1D_ohaver()[0]
print(P)
for peak in P['position']:
    print(peak)
    print(hs.eds.get_xray_lines_near_energy(peak, only_lines=['a', 'b']))
# Out:
# [########################################] | 100% Completed | 108.93 ms
# [########################################] | 100% Completed | 114.74 ms
# [########################################] | 100% Completed | 218.45 ms
# [( 0.01789093,  49.63826657, 0.06950149)
#  ( 1.10579383, 128.90055035, 0.11039993)
#  ( 1.29377947,  86.78523218, 0.1219683 )
#  ( 9.23792958,  82.2448964 , 0.24377416)
#  (10.5238407 ,  64.18895966, 0.2626254 )]
# 0.017890934637213078
# ['He_Ka', 'H_Ka', 'Be_Ka']
# 1.1057938307481758
# ['Sm_Mb', 'Eu_Ma', 'Ga_La', 'Ga_Lb1', 'Na_Kb', 'Eu_Mb', 'Pm_Mb', 'Sm_Ma', 'Na_Ka', 'Gd_Ma', 'Zn_Lb1', 'Ge_La', 'Zn_La']
# 1.2937794664549631
# ['Dy_Ma', 'Mg_Kb', 'As_La', 'As_Lb1', 'Tb_Mb', 'Dy_Mb', 'Mg_Ka', 'Ho_Ma', 'Tb_Ma', 'Ge_Lb1', 'Se_La', 'Gd_Mb', 'Ho_Mb']
# 9.237929576536711
# ['Ga_Ka', 'Ir_La']
# 10.523840702417887
# ['As_Ka', 'Pb_La']

# %%
plotly_plot_multiple_spectra(ga30)

# %%
from scipy.signal import find_peaks
find_peaks(ga30[0][1], prominence=0.001)
# Out:
# (array([  22,   47,   72,  117,  131,  149,  195,  263,  288,  301,  340,
#          346,  349,  362,  383,  388,  414,  428,  463,  488,  535,  606,
#          758,  807,  873,  944, 1046, 1072, 1191], dtype=int64),
#  {'prominences': array([0.11115606, 0.01728226, 0.0014646 , 0.01788205, 0.99937231,
#          0.36621938, 0.00753222, 0.0014367 , 0.00108799, 0.00107404,
#          0.0010043 , 0.00145065, 0.00110194, 0.00124142, 0.0010043 ,
#          0.00924789, 0.00129722, 0.00154829, 0.00114378, 0.00126932,
#          0.0019528 , 0.0010043 , 0.00121352, 0.00106009, 0.00118563,
#          0.35204765, 0.0169475 , 0.19473581, 0.02802265]),
#   'left_bases': array([  12,   32,   54,   32,   12,  141,  178,  210,  210,  210,  210,
#           178,  348,  348,  178,  178,  406,  406,  456,  485,  533,  601,
#           731,  803,  869,  178,  997,  997, 1144], dtype=int64),
#   'right_bases': array([  32,   54,   76,  121, 2022, 2022,  210,  269,  295,  305,  344,
# ...

# %%
get_spesific_lines_from_hspy(['Cs'])
# Out:
# {'Cs': {'Lb1': {'weight': 0.42983, 'energy (keV)': 4.6199},
#   'Kb': {'weight': 0.15, 'energy (keV)': 34.987},
#   'Ka': {'weight': 1.0, 'energy (keV)': 30.9727},
#   'Lb2': {'weight': 0.19589, 'energy (keV)': 4.9354},
#   'Lb4': {'weight': 0.08869, 'energy (keV)': 4.6493},
#   'La': {'weight': 1.0, 'energy (keV)': 4.2864},
#   'Ln': {'weight': 0.0152, 'energy (keV)': 4.1423},
#   'Ll': {'weight': 0.04269, 'energy (keV)': 3.7948},
#   'Lb3': {'weight': 0.1399, 'energy (keV)': 4.7167},
#   'Lg3': {'weight': 0.0325, 'energy (keV)': 5.5527},
#   'Lg1': {'weight': 0.07215, 'energy (keV)': 5.2806}}}

# %%
get_spesific_lines_from_hspy(['O'])
# Out:
# {'O': {'Ka': {'weight': 1.0, 'energy (keV)': 0.5249}}}

# %%
hs.eds.get_xray_lines_near_energy(4.61)
# The lines are returned in order of distance from the specified energy, and can be limited by additional, optional arguments.
# Out:
# ['Cs_Lb1',
#  'Sb_Lg3',
#  'Nd_Ll',
#  'Te_Lg1',
#  'Cs_Lb4',
#  'La_La',
#  'La_Ln',
#  'Xe_Lb3',
#  'Ti_Ka']

# %%
al = "Al"

type(hs.material.elements[al])
# Out:
# hyperspy.misc.utils.DictionaryTreeBrowser

# %%
hs.material.elements[al]["Atomic_properties"]
# hs.material.elements[al].Atomic_properties
# Out:
# ├── Binding_energies
# │   ├── K
# │   │   ├── edge = Abrupt onset
# │   │   ├── onset_energy (eV) = 1560.0
# │   │   ├── relevance = Major
# │   │   └── threshold =
# │   ├── L1
# │   │   ├── edge = Abrupt onset
# │   │   ├── onset_energy (eV) = 118.0
# │   │   ├── relevance = Minor
# │   │   └── threshold =
# │   └── L2,3
# │       ├── edge = Delayed maximum
# │       ├── onset_energy (eV) = 73.0
# │       ├── relevance = Major
# │       └── threshold = Sharp peak
# └── Xray_lines
#     ├── Ka
#     │   ├── energy (keV) = 1.4865
#     │   └── weight = 1.0
#     └── Kb
#         ├── energy (keV) = 1.5596
#         └── weight = 0.0132
